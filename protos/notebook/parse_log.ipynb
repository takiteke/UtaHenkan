# %%
import json
import os
os.chdir("C:\\Users\\TakaiYohei\\Desktop\\UtaHenkan\\protos")
import matplotlib.pyplot as plt

# %%
log = open('../output_unrevarb_lam1=10/log', 'r')

# %%
js_log = json.load(log)

# %%
js_log[0]
# Out:
# {'dec/loss': 1.9614131450653076,
#  'dis/loss': 1.5913108587265015,
#  'elapsed_time': 13.306701717045172,
#  'enc/loss': 1.9614131450653076,
#  'epoch': 0,
#  'iteration': 20}

# %%
len_log = len(js_log)
dec_loss_list = []
dis_loss_list = []
for i in range(len_log):
    dec_loss_list.append(js_log[i]['dec/loss'])
    dis_loss_list.append(js_log[i]['dis/loss'])

# %%
#plt.plot(range(len_log), dec_loss_list)
plt.plot(range(len_log), dis_loss_list)
plt.show()
