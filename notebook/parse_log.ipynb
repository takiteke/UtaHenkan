# %%
import json
import os
os.chdir("C:\\Users\\TakaiYohei\\Desktop\\UtaHenkan\\protos")
import matplotlib.pyplot as plt

# %%
log = open('../output_ran/log', 'r')
log2 = open('../output_2334/log', 'r')

# %%
js_log = json.load(log)
js_log2 = json.load(log2)
print(len(js_log))
# Out:
# 17014

# %%
len_log = len(js_log)
dec_loss_list = []
dis_loss_list = []
for i in range(len_log):
    dec_loss_list.append(js_log[i]['dec/loss'])
    dis_loss_list.append(js_log[i]['dis/loss'])

# %%
len_log2 = len(js_log2)
dec_loss_list2 = []
dis_loss_list2 = []
for i in range(len_log2):
    dec_loss_list2.append(js_log2[i]['dec/loss'])
    dis_loss_list2.append(js_log2[i]['dis/loss'])

# %%
#plt.plot(range(len_log), dec_loss_list)
plt.plot(range(len_log), dis_loss_list)
plt.plot(range(len_log2), dis_loss_list2)
plt.show()
